# %%
import pandas as pd
# %matplotlib inline

# %%
# df=pd.read_excel("https://github.com/prasertcbs/basic-dataset/raw/master/Car1_whole2559.xls")
# df=pd.read_excel("https://github.com/prasertcbs/basic-dataset/raw/master/Car1_whole2559.xls",sheet_name="Total",skiprows=6)
# df=pd.read_excel("https://github.com/prasertcbs/basic-dataset/raw/master/Car1_whole2559.xls",sheet_name="Total",skiprows=6,skipfooter=3,usecols="B:I")
info=["Seq","Brand","1300cc","1600cc","1800cc","2000cc","Gtc2000cc","elec","Total"]
df=pd.read_excel("https://github.com/prasertcbs/basic-dataset/raw/master/Car1_whole2559.xls",sheet_name="Total",skiprows=7,header=None,names=info,skipfooter=3)
df
# Out:
#     Seq          Brand  1300cc  1600cc  1800cc  2000cc  Gtc2000cc  elec  \
# 0     1     ALFA ROMEO       0       0       3       0          3     0
# 1     2   ASTON MARTIN       0       0       0       0         14     0
# 2     3           AUDI       0       4       0     111          9     0
# 3     4         AUSTIN       0       0       0       0          0     0
# 4     5        BENTLEY       0       0       0       0         15     0
# 5     6            BMW       2     596       0    6159        562     0
# 6     7       CADILLAC       0       0       0       0          5     0
# 7     8          CHERY       0       0       0       3          0     0
# 8     9      CHEVROLET       0     409     413     651       5469     0
# 9    10       CHRYSLER       0       0       0       1          0     0
# 10   11        CITROEN       1       4       0       0          0     0
# 11   12         DAEWOO       0       0       0       0          0     0
# ...

# %%
df=df.drop("Seq",axis=1)
# Out:
#             Brand  1300cc  1600cc  1800cc  2000cc  Gtc2000cc  elec   Total
# 0      ALFA ROMEO       0       0       3       0          3     0       6
# 1    ASTON MARTIN       0       0       0       0         14     0      14
# 2            AUDI       0       4       0     111          9     0     124
# 3          AUSTIN       0       0       0       0          0     0       0
# 4         BENTLEY       0       0       0       0         15     0      15
# 5             BMW       2     596       0    6159        562     0    7319
# 6        CADILLAC       0       0       0       0          5     0       5
# 7           CHERY       0       0       0       3          0     0       3
# 8       CHEVROLET       0     409     413     651       5469     0    6942
# 9        CHRYSLER       0       0       0       1          0     0       1
# 10        CITROEN       1       4       0       0          0     0       5
# ...

# %%
df=df.set_index("Brand",inplace=None)
# Out:
#                Seq  1300cc  1600cc  1800cc  2000cc  Gtc2000cc  elec   Total
# Brand
# ALFA ROMEO       1       0       0       3       0          3     0       6
# ASTON MARTIN     2       0       0       0       0         14     0      14
# AUDI             3       0       4       0     111          9     0     124
# AUSTIN           4       0       0       0       0          0     0       0
# BENTLEY          5       0       0       0       0         15     0      15
# BMW              6       2     596       0    6159        562     0    7319
# CADILLAC         7       0       0       0       0          5     0       5
# CHERY            8       0       0       0       3          0     0       3
# CHEVROLET        9       0     409     413     651       5469     0    6942
# CHRYSLER        10       0       0       0       1          0     0       1
# CITROEN         11       1       4       0       0          0     0       5
# ...

# %%
df=df[df.Total!=0]
df.nlargest(10,"Total")
# Out:
#     Seq          Brand  1300cc  1600cc  1800cc  2000cc  Gtc2000cc  elec  \
# 60   61         TOYOTA   37713   36105    7715    4359      72058     0
# 21   22          HONDA    1890   69590   32547    9524       2575     0
# 24   25          ISUZU       0       0       0   35943      12144     0
# 39   40     MITSUBISHI   15342       3      64     173      32286     0
# 35   36          MAZDA   14962    8423       0   11384       5137     0
# 42   43         NISSAN   17541    4125     522    5325       5243     0
# 17   18           FORD     315    3910       1     294      25911     0
# 58   59         SUZUKI   18217     892       0       3          0     0
# 36   37  MERCEDES BENZ       1    1583     335    5441       5271     0
# 5     6            BMW       2     596       0    6159        562     0
#
#      Total
# 60  157950
# 21  116126
# 24   48087
# 39   47868
# 35   39906
# 42   32756
# 17   30431
# 58   19112
# 36   12631
# 5     7319

# %%
df.nlargest(10,"Total")["Total"].sort_values().plot(kind='barh')
