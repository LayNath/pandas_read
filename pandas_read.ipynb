# %%
import pandas as pd

# %%
url="https://github.com/AddisonGauss/NbaData2015-2016/raw/master/nbasalaries.csv"
pd.read_csv(url)
# Out:
#      Unnamed: 0   RK                  Player                   TEAM  \
# 0             0    1             Kobe Bryant     Los Angeles Lakers
# 1             1    2            LeBron James    Cleveland Cavaliers
# 2             2    3         Carmelo Anthony        New York Knicks
# 3             3    4           Dwight Howard        Houston Rockets
# 4             4    5              Chris Bosh             Miami Heat
# 5             5    6              Chris Paul            LA Clippers
# 6             6    7            Kevin Durant  Oklahoma City Thunder
# 7             7    8            Derrick Rose          Chicago Bulls
# 8             8    9             Dwyane Wade             Miami Heat
# 9             9   10       LaMarcus Aldridge      San Antonio Spurs
# 10           10   11              Kevin Love    Cleveland Cavaliers
# 11           11   12              Marc Gasol      Memphis Grizzlies
# 12           12   13           Blake Griffin            LA Clippers
# ...

# %%
url="https://github.com/ibm-watson-data-lab/open-data/raw/master/movies/movies.tsv"
pd.read_table(url)
# Out:
#           id                                            name  year rating  \
# 0     499549                                          Avatar  2009   PG13
# 1     120338                                         Titanic  1997   PG13
# 2     848228                                    The Avengers  2012   PG13
# 3     468569                                 The Dark Knight  2008   PG13
# 4      76759                                       Star Wars  1977     PG
# 5    1345836                           The Dark Knight Rises  2012   PG13
# 6     298148                                         Shrek 2  2004     PG
# 7      83866                      E.T. the Extra-Terrestrial  1982     PG
# 8     120915       Star Wars: Episode I - The Phantom Menace  1999     PG
# 9     383574      Pirates of the Caribbean: Dead Man's Chest  2006   PG13
# 10    435761                                     Toy Story 3  2010      G
# 11   1392170                                The Hunger Games  2012   PG13
# ...

# %%
url="https://github.com/h2oai/h2o-2/raw/master/smalldata/iris/iris.xlsx"
pd.read_excel(url)
# Out:
#      sepal_len  sepal_wid  petal_len  petal_wid           class
# 0          5.1        3.5        1.4        0.2     Iris-setosa
# 1          4.9        3.0        1.4        0.2     Iris-setosa
# 2          4.7        3.2        1.3        0.2     Iris-setosa
# 3          4.6        3.1        1.5        0.2     Iris-setosa
# 4          5.0        3.6        1.4        0.2     Iris-setosa
# 5          5.4        3.9        1.7        0.4     Iris-setosa
# 6          4.6        3.4        1.4        0.3     Iris-setosa
# 7          5.0        3.4        1.5        0.2     Iris-setosa
# 8          4.4        2.9        1.4        0.2     Iris-setosa
# 9          4.9        3.1        1.5        0.1     Iris-setosa
# 10         5.4        3.7        1.5        0.2     Iris-setosa
# 11         4.8        3.4        1.6        0.2     Iris-setosa
# 12         4.8        3.0        1.4        0.1     Iris-setosa
# 13         4.3        3.0        1.1        0.1     Iris-setosa
# ...

# %%
url="https://github.com/prasertcbs/test/raw/master/fwf_no_header.txt"
pd.read_fwf(url,widths=[5,7,1],names=["Student_Id","Course_"])
